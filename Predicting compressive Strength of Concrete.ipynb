# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv(r"C:\Users\AZMA\Downloads\Concrete_Data.csv")

# %%
dataset
# Out:
#       Cement (component 1)(kg in a m^3 mixture)  \
# 0                                         540.0
# 1                                         540.0
# 2                                         332.5
# 3                                         332.5
# 4                                         198.6
# ...                                         ...
# 1025                                      276.4
# 1026                                      322.2
# 1027                                      148.5
# 1028                                      159.1
# 1029                                      260.9
#
#       Blast Furnace Slag (component 2)(kg in a m^3 mixture)  \
# 0                                                   0.0
# 1                                                   0.0
# 2                                                 142.5
# 3                                                 142.5
# 4                                                 132.4
# ...

# %%
dataset.corr()
# Out:
#                                                     Cement (component 1)(kg in a m^3 mixture)  \
# Cement (component 1)(kg in a m^3 mixture)                                            1.000000
# Blast Furnace Slag (component 2)(kg in a m^3 mi...                                  -0.275216
# Fly Ash (component 3)(kg in a m^3 mixture)                                          -0.397467
# Water  (component 4)(kg in a m^3 mixture)                                           -0.081587
# Superplasticizer (component 5)(kg in a m^3 mixt...                                   0.092386
# Coarse Aggregate  (component 6)(kg in a m^3 mix...                                  -0.109349
# Fine Aggregate (component 7)(kg in a m^3 mixture)                                   -0.222718
# Age (day)                                                                            0.081946
# Concrete compressive strength(MPa, megapascals)                                      0.497832
#
# ...

# %%
import seaborn as sns
sns.heatmap(dataset.corr(),annot=True)

# %%
dataset.describe()
# Out:
#        Cement (component 1)(kg in a m^3 mixture)  \
# count                                1030.000000
# mean                                  281.167864
# std                                   104.506364
# min                                   102.000000
# 25%                                   192.375000
# 50%                                   272.900000
# 75%                                   350.000000
# max                                   540.000000
#
#        Blast Furnace Slag (component 2)(kg in a m^3 mixture)  \
# count                                        1030.000000
# mean                                           73.895825
# std                                            86.279342
# min                                             0.000000
# 25%                                             0.000000
# 50%                                            22.000000
# 75%                                           142.950000
# ...

# %%
sns.boxplot(dataset["Cement (component 1)(kg in a m^3 mixture)"])

# %%
sns.boxplot(dataset["Blast Furnace Slag (component 2)(kg in a m^3 mixture)"])

# %%
sns.boxplot(dataset["Fly Ash (component 3)(kg in a m^3 mixture)"])

# %%
sns.boxplot(dataset["Fine Aggregate (component 7)(kg in a m^3 mixture)"])

# %%
dataset.isnull().sum()
# Out:
# Cement (component 1)(kg in a m^3 mixture)                0
# Blast Furnace Slag (component 2)(kg in a m^3 mixture)    0
# Fly Ash (component 3)(kg in a m^3 mixture)               0
# Water  (component 4)(kg in a m^3 mixture)                0
# Superplasticizer (component 5)(kg in a m^3 mixture)      0
# Coarse Aggregate  (component 6)(kg in a m^3 mixture)     0
# Fine Aggregate (component 7)(kg in a m^3 mixture)        0
# Age (day)                                                0
# Concrete compressive strength(MPa, megapascals)          0
# dtype: int64

# %%
dataset
# Out:
#       Cement (component 1)(kg in a m^3 mixture)  \
# 0                                         540.0
# 1                                         540.0
# 2                                         332.5
# 3                                         332.5
# 4                                         198.6
# ...                                         ...
# 1025                                      276.4
# 1026                                      322.2
# 1027                                      148.5
# 1028                                      159.1
# 1029                                      260.9
#
#       Blast Furnace Slag (component 2)(kg in a m^3 mixture)  \
# 0                                                   0.0
# 1                                                   0.0
# 2                                                 142.5
# 3                                                 142.5
# 4                                                 132.4
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 9 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   Cement (component 1)(kg in a m^3 mixture)              1030 non-null   float64
#  1   Blast Furnace Slag (component 2)(kg in a m^3 mixture)  1030 non-null   float64
#  2   Fly Ash (component 3)(kg in a m^3 mixture)             1030 non-null   float64
#  3   Water  (component 4)(kg in a m^3 mixture)              1030 non-null   float64
#  4   Superplasticizer (component 5)(kg in a m^3 mixture)    1030 non-null   float64
#  5   Coarse Aggregate  (component 6)(kg in a m^3 mixture)   1030 non-null   float64
#  6   Fine Aggregate (component 7)(kg in a m^3 mixture)      1030 non-null   float64
#  7   Age (day)                                              1030 non-null   int64
# ...

# %%
x=dataset.iloc[:,0:8].values
y=dataset.iloc[:,8:9].values

# %%
x.shape
# Out:
# (1030, 8)

# %%
x
# Out:
# array([[ 540. ,    0. ,    0. , ..., 1040. ,  676. ,   28. ],
#        [ 540. ,    0. ,    0. , ..., 1055. ,  676. ,   28. ],
#        [ 332.5,  142.5,    0. , ...,  932. ,  594. ,  270. ],
#        ...,
#        [ 148.5,  139.4,  108.6, ...,  892.4,  780. ,   28. ],
#        [ 159.1,  186.7,    0. , ...,  989.6,  788.9,   28. ],
#        [ 260.9,  100.5,   78.3, ...,  864.5,  761.5,   28. ]])

# %%
y
# Out:
# array([[79.99],
#        [61.89],
#        [40.27],
#        ...,
#        [23.7 ],
#        [32.77],
#        [32.4 ]])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train
# Out:
# array([[ 480. ,    0. ,    0. , ...,  936. ,  721. ,   28. ],
#        [ 375. ,    0. ,    0. , ..., 1038. ,  758. ,   28. ],
#        [ 303.6,  139.9,    0. , ...,  895.5,  722.5,   28. ],
#        ...,
#        [ 144. ,    0. ,  175. , ...,  943. ,  844. ,   28. ],
#        [ 239.6,  359.4,    0. , ...,  941.6,  664.3,   28. ],
#        [ 192. ,  288. ,    0. , ...,  929.8,  716.1,   90. ]])

# %%
y_train
# Out:
# array([[43.89],
#        [38.21],
#        [33.42],
#        [13.12],
#        [47.22],
#        [22.32],
#        [12.47],
#        [28.94],
#        [47.03],
#        [26.32],
#        [30.44],
#        [12.64],
#        [20.77],
#        [43.8 ],
#        [66.1 ],
#        [15.36],
#        [40.87],
#        [45.94],
#        [33.76],
#        [43.58],
#        [23.52],
#        [42.7 ],
#        [14.14],
#        [48.4 ],
#        [34.57],
#        [35.86],
#        [59.09],
#        [24.5 ],
#        [37.72],
#        [15.52],
#        [32.4 ],
#        [33.05],
#        [49.25],
#        [71.7 ],
#        [54.9 ],
#        [50.46],
#        [51.86],
#        [28.68],
#        [26.77],
#        [17.24],
#        [36.84],
#        [40.23],
#        [47.71],
#        [11.36],
#        [ 9.99],
#        [40.93],
#        [40.56],
#        [31.72],
#        [39.42],
#        [18.13],
#        [18.28],
#        [ 9.87],
#        [41.3 ],
#        [34.56],
#        [53.96],
# ...

# %% [markdown]
# # multi linear-regression

# %%
from sklearn.linear_model import LinearRegression
mlr=LinearRegression()
mlr.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
x_test
# Out:
# array([[ 500. ,    0. ,    0. , ..., 1125. ,  613. ,    3. ],
#        [ 122.6,  183.9,    0. , ...,  958.2,  800.1,    7. ],
#        [ 362.6,  189. ,    0. , ...,  944.7,  755.8,   91. ],
#        ...,
#        [ 173.5,   50.1,  173.5, ..., 1006.2,  793.5,   14. ],
#        [ 262. ,  111. ,   86. , ...,  895. ,  733. ,   28. ],
#        [ 250. ,    0. ,   95.7, ...,  956.9,  861.2,    3. ]])

# %%
y_pred=mlr.predict(x_test)

# %%
y_pred
# Out:
# array([[39.16168311],
#        [14.61985573],
#        [61.44006681],
#        [53.77704184],
#        [24.66843056],
#        [53.44824826],
#        [46.03635103],
#        [27.0142886 ],
#        [52.97935681],
#        [37.7669688 ],
#        [16.78225173],
#        [39.38067954],
#        [29.58730029],
#        [35.96292876],
#        [47.58040332],
#        [56.53181108],
#        [35.48381341],
#        [29.5710143 ],
#        [48.31448876],
#        [35.09926523],
#        [53.50039223],
#        [32.6381569 ],
#        [32.78602889],
#        [47.85367457],
#        [23.52304214],
#        [23.49824614],
#        [69.33646719],
#        [26.46234841],
#        [56.53181108],
#        [48.29138728],
#        [18.94539881],
#        [36.73148524],
#        [17.69801487],
#        [19.85998727],
#        [24.52854945],
#        [15.47194289],
#        [52.98743408],
#        [27.88380095],
#        [27.4939795 ],
#        [26.11003546],
#        [52.37737924],
# ...

# %%
y_test
# Out:
# array([[26.06],
#        [10.35],
#        [79.3 ],
#        [74.99],
#        [ 9.69],
#        [47.1 ],
#        [59.  ],
#        [22.72],
#        [61.89],
#        [52.12],
#        [17.54],
#        [48.15],
#        [38.33],
#        [17.2 ],
#        [56.83],
#        [55.25],
#        [33.36],
#        [34.68],
#        [52.61],
#        [39.94],
#        [61.46],
#        [27.63],
#        [32.9 ],
#        [41.64],
#        [17.54],
#        [26.85],
#        [66.9 ],
#        [21.06],
#        [61.07],
#        [66.95],
#        [20.87],
#        [48.79],
#        [24.05],
#        [47.81],
#        [21.16],
#        [ 6.94],
#        [28.6 ],
#        [26.31],
#        [33.95],
#        [25.72],
#        [37.8 ],
#        [35.17],
#        [32.24],
#        [37.81],
#        [57.23],
#        [33.4 ],
#        [30.14],
#        [33.8 ],
#        [35.08],
#        [52.91],
#        [40.93],
#        [21.75],
#        [16.5 ],
#        [42.35],
#        [50.94],
# ...

# %%
from sklearn.metrics import r2_score
accuracy=r2_score(y_test,y_pred)

# %%
accuracy
# Out:
# 0.6369606518338298

# %%
yp=mlr.predict([[475,0,0,228,0,932,594,180]])

# %%
yp
# Out:
# array([[47.78172386]])

# %% [markdown]
# # ANN

# %%
from keras.models import Sequential
from keras.layers import Dense
# Out:
# Using TensorFlow backend.
# C:\Users\AZMA\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\AZMA\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\AZMA\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
regressor=Sequential()
# Out:
# WARNING:tensorflow:From C:\Users\AZMA\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
x.shape
# Out:
# (1030, 8)

# %%
regressor.add(Dense(units = 8,activation = "relu", init ="random_uniform"))#input layer
# Out:
# C:\Users\AZMA\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=8, activation="relu", kernel_initializer="random_uniform")`
#   """Entry point for launching an IPython kernel.

# %%
regressor.add(Dense(units = 16,activation = "relu", init ="random_uniform"))#hidden layer-1
# Out:
# C:\Users\AZMA\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=16, activation="relu", kernel_initializer="random_uniform")`
#   """Entry point for launching an IPython kernel.

# %%
regressor.add(Dense(units = 24,activation = "relu", init ="random_uniform"))#hidden layer-2
# Out:
# C:\Users\AZMA\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=24, activation="relu", kernel_initializer="random_uniform")`
#   """Entry point for launching an IPython kernel.

# %%
regressor.add(Dense(units = 1,init ="random_uniform"))#output layer
# Out:
# C:\Users\AZMA\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(units=1, kernel_initializer="random_uniform")`
#   """Entry point for launching an IPython kernel.

# %%
regressor.compile(optimizer = "adam",loss = "mean_squared_error",metrics = ["mse"])
# Out:
# WARNING:tensorflow:From C:\Users\AZMA\anaconda3\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
regressor.fit(x_train,y_train, epochs = 10000,batch_size = 32)
# Out:
# WARNING:tensorflow:From C:\Users\AZMA\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\AZMA\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From C:\Users\AZMA\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From C:\Users\AZMA\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/10000
# 824/824 [==============================] - 1s 982us/step - loss: 1562.7611 - mean_squared_error: 1562.7611
# Epoch 2/10000
# ...

# %%
y_pred = regressor.predict(x_test)

# %%
y_pred
# Out:
# array([[24.775585 ],
#        [10.315447 ],
#        [75.69359  ],
#        [73.91434  ],
#        [ 9.373518 ],
#        [40.946556 ],
#        [49.676422 ],
#        [24.576126 ],
#        [65.121956 ],
#        [48.868073 ],
#        [17.805882 ],
#        [47.36932  ],
#        [34.506115 ],
#        [18.023151 ],
#        [55.371643 ],
#        [65.548164 ],
#        [37.96879  ],
#        [35.654457 ],
#        [40.78608  ],
#        [37.087612 ],
#        [64.3176   ],
#        [27.643467 ],
#        [27.415646 ],
#        [31.603928 ],
#        [17.142035 ],
#        [27.473217 ],
#        [62.616184 ],
#        [24.873163 ],
#        [65.548164 ],
#        [61.54001  ],
#        [19.970074 ],
#        [41.768517 ],
#        [24.930134 ],
#        [31.168259 ],
#        [17.961311 ],
#        [ 6.761409 ],
#        [35.33808  ],
#        [30.7003   ],
#        [31.053154 ],
#        [27.675526 ],
#        [44.875847 ],
#        [35.81525  ],
#        [26.82837  ],
# ...

# %%
y_test
# Out:
# array([[26.06],
#        [10.35],
#        [79.3 ],
#        [74.99],
#        [ 9.69],
#        [47.1 ],
#        [59.  ],
#        [22.72],
#        [61.89],
#        [52.12],
#        [17.54],
#        [48.15],
#        [38.33],
#        [17.2 ],
#        [56.83],
#        [55.25],
#        [33.36],
#        [34.68],
#        [52.61],
#        [39.94],
#        [61.46],
#        [27.63],
#        [32.9 ],
#        [41.64],
#        [17.54],
#        [26.85],
#        [66.9 ],
#        [21.06],
#        [61.07],
#        [66.95],
#        [20.87],
#        [48.79],
#        [24.05],
#        [47.81],
#        [21.16],
#        [ 6.94],
#        [28.6 ],
#        [26.31],
#        [33.95],
#        [25.72],
#        [37.8 ],
#        [35.17],
#        [32.24],
#        [37.81],
#        [57.23],
#        [33.4 ],
#        [30.14],
#        [33.8 ],
#        [35.08],
#        [52.91],
#        [40.93],
#        [21.75],
#        [16.5 ],
#        [42.35],
#        [50.94],
# ...

# %%
yp1=regressor.predict(np.array([[475,0,0,228,0,932,594,180]]))

# %%
yp1
# Out:
# array([[40.15816]], dtype=float32)

# %%
from sklearn.metrics import r2_score
accuracy=r2_score(y_test,y_pred)

# %%
accuracy
# Out:
# 0.8661627146965571

# %%
regressor.save("concrete.h5")

# %% [markdown]
# # Random forest regressor

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf= RandomForestRegressor(n_estimators=100,criterion="mse",random_state=0)
rf.fit(x_train,y_train)
# Out:
# C:\Users\AZMA\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=0, verbose=0, warm_start=False)

# %%
y_pred=rf.predict(x_test)
y_pred
# Out:
# array([20.90626667,  7.9139    , 79.142     , 62.2535    , 11.2587    ,
#        48.98446429, 59.7304    , 23.3658    , 72.1763    , 51.7193    ,
#        18.6964    , 42.6562    , 35.908     , 15.3773    , 53.434     ,
#        56.5536    , 38.4633    , 34.7529    , 50.99423333, 38.1745    ,
#        58.400225  , 28.9577    , 27.1672    , 39.70853333, 16.0212    ,
#        25.6316    , 62.8931    , 25.6034    , 56.5536    , 62.1483    ,
#        20.4563    , 45.4644    , 27.5014    , 37.3801    , 20.8898    ,
#         9.084     , 33.5738    , 26.7014    , 34.3786    , 32.9772    ,
#        35.93693333, 35.6629    , 31.7536    , 38.8416    , 59.89492   ,
#        33.634     , 27.020175  , 33.04946667, 34.2663625 , 51.0632    ,
#        43.1804    , 25.7381    , 22.9847    , 38.535     , 53.5379    ,
#        45.6786    , 44.2364    , 53.7141    , 64.2206    , 37.6014    ,
#        36.0512    , 22.4055    , 59.28737333, 46.06011429, 12.5617    ,
# ...

# %%
from sklearn.metrics import r2_score
rf_accuracy=r2_score(y_test,y_pred)

# %%
rf_accuracy
# Out:
# 0.9254656405872087

# %%
yp1=rf.predict([[475,0,0,228,0,932,594,180]])

# %%
yp1
# Out:
# array([42.6085])

# %% [markdown]
# # decision tree regressor

# %%
from sklearn.tree import DecisionTreeRegressor
decisiontree=DecisionTreeRegressor(random_state=42)
decisiontree.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=42, splitter='best')

# %%
dpred=decisiontree.predict(x_test)

# %%
dpred
# Out:
# array([12.64 ,  7.51 , 79.3  , 56.4  ,  4.9  , 46.8  , 58.52 , 23.51 ,
#        79.99 , 56.14 , 17.58 , 40.39 , 29.45 , 12.37 , 68.3  , 56.14 ,
#        41.89 , 35.76 , 59.76 , 35.87 , 56.34 , 26.94 , 21.6  , 59.76 ,
#        14.54 , 25.18 , 60.29 , 31.35 , 56.14 , 66.82 , 17.58 , 48.85 ,
#        28.02 , 27.83 , 21.18 ,  4.9  , 35.3  , 29.55 , 30.88 , 37.27 ,
#        39.3  , 31.35 , 32.25 , 44.61 , 38.46 , 33.4  , 24.07 , 42.42 ,
#        32.82 , 51.73 , 42.14 , 27.83 , 16.5  , 40.71 , 48.99 , 43.94 ,
#        67.87 , 47.72 , 64.3  , 36.97 , 38.21 , 20.08 , 67.765, 59.09 ,
#        17.17 , 67.7  , 33.04 , 28.99 , 13.2  , 14.84 , 12.55 , 27.77 ,
#        49.2  , 27.83 , 67.7  , 30.19 , 40.23 , 15.03 , 40.06 , 42.03 ,
#        17.22 , 51.04 , 15.34 , 34.24 , 52.04 , 47.4  , 36.84 , 47.72 ,
#        38.63 , 38.56 , 62.05 , 14.99 , 12.55 , 50.6  , 15.57 , 39.78 ,
#        12.55 , 41.54 , 46.68 , 40.06 , 19.42 , 23.52 , 31.25 , 29.87 ,
# ...

# %%
y_test
# Out:
# array([[26.06],
#        [10.35],
#        [79.3 ],
#        [74.99],
#        [ 9.69],
#        [47.1 ],
#        [59.  ],
#        [22.72],
#        [61.89],
#        [52.12],
#        [17.54],
#        [48.15],
#        [38.33],
#        [17.2 ],
#        [56.83],
#        [55.25],
#        [33.36],
#        [34.68],
#        [52.61],
#        [39.94],
#        [61.46],
#        [27.63],
#        [32.9 ],
#        [41.64],
#        [17.54],
#        [26.85],
#        [66.9 ],
#        [21.06],
#        [61.07],
#        [66.95],
#        [20.87],
#        [48.79],
#        [24.05],
#        [47.81],
#        [21.16],
#        [ 6.94],
#        [28.6 ],
#        [26.31],
#        [33.95],
#        [25.72],
#        [37.8 ],
#        [35.17],
#        [32.24],
#        [37.81],
#        [57.23],
#        [33.4 ],
#        [30.14],
#        [33.8 ],
#        [35.08],
#        [52.91],
#        [40.93],
#        [21.75],
#        [16.5 ],
#        [42.35],
#        [50.94],
# ...

# %%
from sklearn.metrics import r2_score
daccuracy=r2_score(y_test,dpred)

# %%
daccuracy
# Out:
# 0.7832927119128332

# %%
yp1=decisiontree.predict([[475,0,0,228,0,932,594,180]])

# %%
yp1
# Out:
# array([42.62])

# %% [raw]
# By applying 4 Algorithms(multiregression,ANN,Randomforest regressor,decision tree regressor) on given dataset,
# random forest regressor algorithm is best for given dataset.
# so we should apply random forest regressor alogoritm for given dataset

# %%
import pickle
pickle.dump(rf,open("concrete.pkl","wb"))
